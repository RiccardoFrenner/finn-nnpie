# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
docs_dir = Path().home() / "Documents/"

# %% [markdown]
# # Analytical Retardations

# %%
Image.open(docs_dir / "Screenshot 2024-10-06 at 13.30.00.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2046x1322>

# %% [markdown]
# # Experimental Data

# %%
Image.open(docs_dir / "Screenshot 2024-10-06 at 21.11.34.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1654x832>

# %% [markdown]
# Caption:
# My training run on the experimental data with as small of an error as the finn paper.
# - Right: Learned Retardation Factor (blue), retardation from finn paper (black)

# %% [markdown]
# ## Pertubed FINN
#
# siehe `analyze_experimental_finn.ipynb`

# %% [markdown]
# # Random Retardations

# %%
Image.open(docs_dir / "Screenshot 2024-10-06 at 12.50.07.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1980x762>

# %% [markdown]
# Caption:
# - Left: Retardations which result in low full-field MSE ( < $10^{-5.5}$) and MAE ( < $5 \cdot 10^{-3}$). Fat: Concentration-producing retardation.
# - Middle and Right: Concentration BTC and Profile for these Retardations.
#
# Analysis:
# - There are Rs that look significantly different but produce almost indistinguishable concentration at certain regions.
# - The Error must come from another not-visible region. Thus, this error can not be detected in the case of experimental data as there is no access to the full field solution.
