# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

# %%
base_dir = Path("../data_out/finn_experimental_data/data_core2/")
# base_dir = Path("../data_out/sythethic_BTC/")
loss = np.loadtxt(base_dir / "loss.txt")
ret_pred = np.load(base_dir / f"predicted_retardations/retPred_{len(loss)}.npy")
c_pred = np.load(base_dir / f"predicted_concentrations/c_pred_{len(loss)}.npy")

# %%
c_pred.shape
# Out:
# (55, 2, 20, 1)

# %%
c_train = np.load(base_dir / "c_train.npy")[:, 0, -1, 0]
c_train.shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 c_train = np.load(base_dir / "c_train.npy")[:, 0, -1, 0]
#       2 c_train.shape
#
# IndexError: too many indices for array: array is 1-dimensional, but 4 were indexed

# %%
plt.plot(c_train, label="train")
plt.plot(c_pred[:, 0, 0, 0]*1e-2, label="pred")
plt.legend()
plt.show()

# %%
plt.colorbar(plt.pcolormesh(c_pred[:, 0, :, 0].T))
plt.show()

# %%
plt.plot(ret_pred)
plt.show()

# %%
loss
# Out:
# array([0.59033579, 0.59033567, 0.59033567, 0.59033567, 0.59033567,
#        0.59033567, 0.59033567, 0.59033567, 0.59033567, 0.59033567])

# %%
plt.plot(loss)
plt.show()
