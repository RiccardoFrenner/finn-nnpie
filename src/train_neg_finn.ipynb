# %%
from pathlib import Path

import torch
import numpy as np
import matplotlib.pyplot as plt

from train_finn import main

# %%
train_data_dir = Path("../data_out/finn_stds_input").resolve()
model, t_train, c_train = main(
    y_train_path=train_data_dir / f"Y_neg_finn_quantile=90.npy",
    output_dir=Path("../data_out/finn_stds_ouput/Y_neg_finn_quantile=90").resolve(),
    train_split_idx=51,
)
# Out:
# Saving files to /Users/r/Documents/stud/ss24/finnpinn/data_out/finn_neg
# Loading data from /Users/r/Documents/stud/ss24/finnpinn/data_out/finn_PI_datasets/Y_neg_finn.npy
# Training: Epoch [2/100], Training Loss: 3.9292, Runtime: 18.2895 secs
# Training: Epoch [3/100], Training Loss: 1.4408, Runtime: 15.6201 secs
# Training: Epoch [4/100], Training Loss: 0.0769, Runtime: 13.8337 secs
# Training: Epoch [5/100], Training Loss: 0.0430, Runtime: 12.7165 secs
# Training: Epoch [6/100], Training Loss: 0.0425, Runtime: 12.9422 secs
# Training: Epoch [7/100], Training Loss: 0.0425, Runtime: 12.6988 secs
# Training: Epoch [8/100], Training Loss: 0.0422, Runtime: 12.8486 secs
# Training: Epoch [9/100], Training Loss: 0.0222, Runtime: 12.5906 secs
# Training: Epoch [10/100], Training Loss: 0.0088, Runtime: 14.0849 secs
# Training: Epoch [11/100], Training Loss: 0.0083, Runtime: 13.7725 secs
# Training: Epoch [12/100], Training Loss: 0.0082, Runtime: 14.0736 secs
# Training: Epoch [13/100], Training Loss: 0.0081, Runtime: 14.7345 secs
# Training: Epoch [14/100], Training Loss: 0.0072, Runtime: 13.9954 secs
# Training: Epoch [15/100], Training Loss: 0.0040, Runtime: 13.5202 secs
# Training: Epoch [16/100], Training Loss: 0.0021, Runtime: 13.9400 secs
# Training: Epoch [17/100], Training Loss: 0.0019, Runtime: 13.1067 secs
# Training: Epoch [18/100], Training Loss: 0.0019, Runtime: 13.2808 secs
# Training: Epoch [19/100], Training Loss: 0.0019, Runtime: 13.5939 secs
# Training: Epoch [20/100], Training Loss: 0.0018, Runtime: 13.1882 secs
# Training: Epoch [21/100], Training Loss: 0.0017, Runtime: 13.3639 secs
# Training: Epoch [22/100], Training Loss: 0.0017, Runtime: 13.1054 secs
# Training: Epoch [23/100], Training Loss: 0.0017, Runtime: 13.1970 secs
# Training: Epoch [24/100], Training Loss: 0.0017, Runtime: 13.3360 secs
# Training: Epoch [25/100], Training Loss: 0.0017, Runtime: 13.4561 secs
# Training: Epoch [26/100], Training Loss: 0.0017, Runtime: 13.4447 secs
# Training: Epoch [27/100], Training Loss: 0.0017, Runtime: 13.2267 secs
# Training: Epoch [28/100], Training Loss: 0.0017, Runtime: 13.5930 secs
# Training: Epoch [29/100], Training Loss: 0.0016, Runtime: 13.6845 secs
# Training: Epoch [30/100], Training Loss: 0.0016, Runtime: 13.7888 secs
# Training: Epoch [31/100], Training Loss: 0.0016, Runtime: 13.9944 secs
# Training: Epoch [32/100], Training Loss: 0.0016, Runtime: 4.0662 secs
# Training: Epoch [33/100], Training Loss: 0.0016, Runtime: 6.8592 secs
# Training: Epoch [34/100], Training Loss: 0.0016, Runtime: 9.0939 secs
# Training: Epoch [35/100], Training Loss: 0.0016, Runtime: 3.4433 secs
# Training: Epoch [36/100], Training Loss: 0.0016, Runtime: 1.4321 secs
# Training: Epoch [37/100], Training Loss: 0.0016, Runtime: 1.3696 secs
# Training: Epoch [80/100], Training Loss: 0.0016, Runtime: 1.3293 secs
# Training: Epoch [81/100], Training Loss: 0.0016, Runtime: 1.4093 secs
# Training: Epoch [82/100], Training Loss: 0.0016, Runtime: 1.5334 secs
# Training: Epoch [83/100], Training Loss: 0.0016, Runtime: 1.4175 secs
# Training: Epoch [84/100], Training Loss: 0.0016, Runtime: 1.4511 secs
# Training: Epoch [85/100], Training Loss: 0.0016, Runtime: 1.3585 secs
# Training: Epoch [86/100], Training Loss: 0.0016, Runtime: 1.4351 secs
# Training: Epoch [87/100], Training Loss: 0.0016, Runtime: 1.4058 secs
# Training: Epoch [88/100], Training Loss: 0.0016, Runtime: 1.5744 secs
# Training: Epoch [89/100], Training Loss: 0.0016, Runtime: 1.4461 secs
# Training: Epoch [90/100], Training Loss: 0.0016, Runtime: 1.3754 secs
# Training: Epoch [91/100], Training Loss: 0.0016, Runtime: 1.4282 secs
# Training: Epoch [92/100], Training Loss: 0.0016, Runtime: 1.3469 secs
# Training: Epoch [93/100], Training Loss: 0.0016, Runtime: 1.4583 secs
# Training: Epoch [94/100], Training Loss: 0.0016, Runtime: 1.4333 secs
# Training: Epoch [95/100], Training Loss: 0.0016, Runtime: 1.4924 secs
# Training: Epoch [96/100], Training Loss: 0.0016, Runtime: 1.4021 secs
# Training: Epoch [97/100], Training Loss: 0.0016, Runtime: 1.3634 secs
# Training: Epoch [98/100], Training Loss: 0.0016, Runtime: 1.4280 secs
# Training: Epoch [99/100], Training Loss: 0.0016, Runtime: 1.4250 secs
# Training: Epoch [100/100], Training Loss: 0.0016, Runtime: 1.3567 secs
# Training: Epoch [101/100], Training Loss: 0.0016, Runtime: 1.4267 secs

# %% [markdown]
# # Analyze Results

# %%
model.eval()
with torch.no_grad():
    c_predictions = model(t_train)
c_predictions = c_predictions.detach().cpu().numpy()
residuals = c_predictions - c_train.numpy()

# %%
print(np.abs(residuals).max())
# Out:
# 0.0025890893

# %%
from math import ceil
ncols = 3
nrows = ceil(26/5)
fig, axs = plt.subplots(ncols=ncols, nrows=nrows, figsize=(8*ncols,8*nrows))
axs = axs.flatten()
for i, ax in zip(range(c_train.shape[2]), axs):
    ax.plot(c_predictions[:, 0, i, 0], label="Pred.")
    ax.plot(c_train[:, 0, i, 0], "k--", label="True.")
plt.legend()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
ax1.pcolor(c_predictions[:, 0, :, 0].T)
ax2.pcolor(c_predictions[:, 1, :, 0].T)
plt.show()

# %% [markdown]
# # Analyze predictions

# %%
from common import plot_c, plot_c_timeseries, plot_c_spaceseries

# %%
print(c_predictions.shape)
# Out:
# (51, 2, 26, 1)

# %% [markdown]
# # Retardation

# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML


def plot_retardation():
    base_dir = Path("../data_out/finn_neg").resolve()

    # Load retardation data for different models
    u = np.load(base_dir / "u_ret.npy")
    retardation_linear = np.load(base_dir / "retardation_linear.npy")
    retardation_freundlich = np.load(base_dir / "retardation_freundlich.npy")
    retardation_langmuir = np.load(base_dir / "retardation_langmuir.npy")

    fig, ax = plt.subplots()
    ax.set_ylim([2, 6])
    plt.plot(u, retardation_linear, linestyle="--", label="Linear")
    plt.plot(u, retardation_freundlich, linestyle="--", label="Freundlich")
    plt.plot(u, retardation_langmuir, linestyle="--", label="Langmuir")

    (ret_pred,) = ax.plot(u, np.zeros_like(u), label="FINN")

    plt.title("Predicted Retardation Factor", fontsize=16)
    plt.xlabel(r"$c_{diss}$ [mg/L]", fontsize=16)
    plt.ylabel(r"$R$", fontsize=16)
    plt.legend(fontsize=16)
    plt.tight_layout()

    pred_ret_path = base_dir / "predicted_retardations"

    def update(file_path):
        ret_pred_data = np.load(file_path)
        ret_pred.set_ydata(ret_pred_data)
        ax.set_ylim([2, 6])
        ax.set_title(f"Predicted Retardation Factor ({file_path.stem})")

    all_files = sorted(
        (p.absolute() for p in pred_ret_path.glob("retPred_*.npy")),
        key=lambda p: int(p.stem.split("_")[-1]),
    )
    files = all_files[:: max(1, len(all_files) // 5)]

    ani = animation.FuncAnimation(fig, update, frames=all_files[::3], interval=200)

    # Save the animation as gif
    ani.save("../retardation_animation.gif", writer="imagemagick")

    # Display the animation in the notebook
    plt.close(fig)
    display(HTML(ani.to_jshtml()))

    # Display static images for the 5 epochs
    fig, axes = plt.subplots(1, len(files), figsize=(4 * len(files), 4))
    for ax, file in zip(axes, files):
        ret_pred_data = np.load(file)
        ax.plot(u, retardation_linear, linestyle="--", label="Linear")
        ax.plot(u, retardation_freundlich, linestyle="--", label="Freundlich")
        ax.plot(u, retardation_langmuir, linestyle="--", label="Langmuir")
        ax.plot(u, ret_pred_data, label="FINN")
        ax.set_title(f"File {file.stem}")
        ax.set_xlabel(r"$c_{diss}$ [mg/L]")
        ax.set_ylabel(r"$R$")
        ax.set_ylim([2, 6])
        ax.legend()

    plt.tight_layout()
    plt.show()

plot_retardation()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img12cf7e4f913442b4b48ef03b0f648376">
#   <div class="anim-controls">
#     <input id="_anim_slider12cf7e4f913442b4b48ef03b0f648376" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim12cf7e4f913442b4b48ef03b0f648376.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim12cf7e4f913442b4b48ef03b0f648376.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim12cf7e4f913442b4b48ef03b0f648376.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim12cf7e4f913442b4b48ef03b0f648376.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim12cf7e4f913442b4b48ef03b0f648376.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim12cf7e4f913442b4b48ef03b0f648376.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim12cf7e4f913442b4b48ef03b0f648376.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim12cf7e4f913442b4b48ef03b0f648376.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim12cf7e4f913442b4b48ef03b0f648376.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim12cf7e4f913442b4b48ef03b0f648376.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select12cf7e4f913442b4b48ef03b0f648376"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_12cf7e4f913442b4b48ef03b0f648376"
#              >
#       <label for="_anim_radio1_12cf7e4f913442b4b48ef03b0f648376">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_12cf7e4f913442b4b48ef03b0f648376"
#              checked>
#       <label for="_anim_radio2_12cf7e4f913442b4b48ef03b0f648376">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_12cf7e4f913442b4b48ef03b0f648376"
#              >
#       <label for="_anim_radio3_12cf7e4f913442b4b48ef03b0f648376">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img12cf7e4f913442b4b48ef03b0f648376";
#     var slider_id = "_anim_slider12cf7e4f913442b4b48ef03b0f648376";
#     var loop_select_id = "_anim_loop_select12cf7e4f913442b4b48ef03b0f648376";
#     var frames = new Array(34);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8fJSN1AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAACSpUlEQ

# %%
import params
x = np.linspace(0.0, params.X, params.Nx)

# %%
X, T = np.meshgrid(x, t_train)
plot_c(t=T, x=X, c=c_predictions[...,0])
plot_c_timeseries(c_predictions[...,0], x_idx=0)
plot_c_timeseries(c_predictions[...,0], x_idx=5)
plot_c_timeseries(c_predictions[...,0], x_idx=10)
plot_c_timeseries(c_predictions[...,0], x_idx=-1)
plt.show()

# %%
plot_c_spaceseries(c_predictions[...,0], t_idx=-1)

# %% [markdown]
# # Training Data

# %%
plot_c(t=T, x=X, c=c_train[...,0])
